# %%
import ultralytics as ul
from PIL import Image
import matplotlib.pyplot as plt

# %%
model = ul.YOLO("yolo11n.pt")

# %%
results = model(["cattle_02.png"])  # results list

# Visualize the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

    # Show results to screen (in supported environments)
    r.show()
# Out:
# 0: 384x640 12 cows, 152.2ms
# Speed: 3.4ms preprocess, 152.2ms inference, 108.6ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Create a new YOLO11n-OBB model from scratch
model = ul.YOLO("yolo11n-obb.yaml")

# %%
results = model(["cattle.png"])  # results list

plt.style.use('dark_background')
# Visualize the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])
    plt.imshow(im_rgb)
    plt.axis('off')
    plt.show()
# Out:
# 0: 512x640 (no detections), 134.0ms
# Speed: 2.0ms preprocess, 134.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
