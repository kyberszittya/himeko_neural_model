# %%
import ultralytics as ul
from PIL import Image
import matplotlib.pyplot as plt

# %%
model = ul.YOLO("yolo11n.pt")

# %%
results = model(["cattle_02.png"])  # results list

# Visualize the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

    # Show results to screen (in supported environments)
    r.show()
# Out:
# 0: 384x640 12 cows, 167.7ms
# Speed: 2.5ms preprocess, 167.7ms inference, 64.8ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Create a new YOLO11n-OBB model from scratch
model = ul.YOLO("yolo11n-obb.yaml")

# %%
results = model(["ami_02.png"])  # results list

plt.style.use('dark_background')
# Visualize the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])
    plt.imshow(im_rgb)
    plt.axis('off')
    plt.show()
# Out:
# 0: 640x480 (no detections), 26.2ms
# Speed: 5.1ms preprocess, 26.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
