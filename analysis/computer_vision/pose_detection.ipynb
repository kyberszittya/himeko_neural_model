# %%
import matplotlib.pyplot as plt
import ultralytics as ul
from PIL import Image

# %%
model = ul.YOLO("yolo11n-pose.pt")

# %%
results = model(["tokyo_02.png"])  # results list
plt.style.use('dark_background')
# Visualize the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])
    plt.imshow(im_rgb)
    plt.show()
# Out:
# 0: 480x640 1 person, 216.1ms
# Speed: 10.0ms preprocess, 216.1ms inference, 173.2ms postprocess per image at shape (1, 3, 480, 640)

# %%
results = model(["cattle.png", "cattle_02.png"])  # results list
plt.style.use('dark_background')
# Visualize the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])
    plt.imshow(im_rgb)
    plt.show()
# Out:
# 0: 640x640 (no detections), 109.7ms
# 1: 640x640 (no detections), 109.7ms
# Speed: 2.0ms preprocess, 109.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
