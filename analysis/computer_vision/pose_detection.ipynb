# %%
import matplotlib.pyplot as plt
import ultralytics as ul
from PIL import Image

# %%
model = ul.YOLO("yolo11n-pose.pt")

# %%
results = model(["tokyo_02.png"])  # results list
plt.style.use('dark_background')
# Visualize the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])
    plt.imshow(im_rgb)
    plt.show()
# Out:
# 0: 480x640 1 person, 173.8ms
# Speed: 7.6ms preprocess, 173.8ms inference, 196.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
results = model(["ami_01.png", "ami_02.png", "ami_03.png"])  # results list
plt.style.use('dark_background')
# Visualize the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])
    plt.imshow(im_rgb)
    plt.show()
# Out:
# 0: 640x480 4 persons, 72.9ms
# 1: 640x480 6 persons, 72.9ms
# 2: 640x480 7 persons, 72.9ms
# Speed: 4.6ms preprocess, 72.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
